# %%
import torch
from torchvision import datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
# %matplotlib inline


train_set = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
# Out:
# 100%|██████████| 9.91M/9.91M [00:03<00:00, 2.82MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 68.5kB/s]
# 100%|██████████| 1.65M/1.65M [00:02<00:00, 810kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.32MB/s]

# %%
# 显示图像
img_per_row = 8
fig = plt.figure(figsize=(10, 10), dpi=80)
for i in range(img_per_row * img_per_row):
    ax = fig.add_subplot(img_per_row, img_per_row, i+1)
    ax.imshow(train_set.data[i].numpy().reshape(28, 28), cmap=plt.cm.binary)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# 定义裁剪转换
c = transforms.CenterCrop((20, 20))
# 定义压缩转换
r = transforms.Resize((8, 8))

# %%
def imshow(img):
    plt.imshow(img.squeeze(0).numpy(), cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
x = train_set[21][0]
imshow(x)

# %%
# 将图片压缩到8x8，用于展示
imshow(r(c(x)))
torch.set_printoptions(precision=2)
print(r(c(x)))
# Out:
# tensor([[[0.00e+00, 0.00e+00, 1.14e-04, 8.99e-03, 1.59e-01, 7.15e-01, 7.28e-01,
#           1.48e-01],
#          [0.00e+00, 0.00e+00, 7.06e-02, 3.87e-01, 7.73e-01, 8.41e-01, 8.24e-01,
#           3.11e-01],
#          [6.84e-04, 7.77e-02, 5.70e-01, 8.12e-01, 8.92e-01, 6.47e-01, 6.88e-01,
#           3.18e-01],
#          [2.73e-02, 5.05e-01, 6.99e-01, 2.61e-01, 3.65e-01, 1.63e-01, 5.26e-01,
#           3.11e-01],
#          [2.78e-01, 7.57e-01, 1.70e-01, 4.31e-03, 8.64e-03, 1.77e-02, 5.31e-01,
#           3.09e-01],
#          [5.63e-01, 7.53e-01, 7.42e-02, 0.00e+00, 2.49e-02, 2.86e-01, 7.00e-01,
#           2.00e-01],
#          [3.81e-01, 8.21e-01, 5.23e-01, 4.22e-01, 5.54e-01, 6.20e-01, 2.41e-01,
#           1.19e-02],
#          [4.08e-02, 3.55e-01, 8.37e-01, 8.56e-01, 5.32e-01, 1.21e-01, 4.53e-03,
#           0.00e+00]]])
